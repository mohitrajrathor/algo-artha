# %% [markdown]
# # Data - prepocessing
# All data that we are going to use will be shown here.

# %%
# libraries that we are going to use.
import pandas as pd
import numpy as np 
import matplotlib.pyplot  as plt
import seaborn as sns
import yfinance as yf
import pandas_ta
import datetime as dt

# %% [markdown]
# ## NSE index lists:
#
# ![image.png](attachment:image.png)
#  **NSE Indices - Market Cap wise illustration*
#
# #### 1. Nifty 50
# > "https://en.wikipedia.org/wiki/NIFTY_50"

# %%
# Fatching data from web 
nifty_50 = pd.read_html("https://en.wikipedia.org/wiki/NIFTY_50")[2]

# let's add it to ../data directory.
nifty_50.to_csv("../data/nifty_50.csv")
