# %% [markdown]
# # API - Tools builder
# To build and check api functionalties and build utility tools.

# %%
# here is the libraries we are going to use.
import pandas as pd             # to analyse data
import numpy as np              # for calculations
import seaborn as sns            # to visualise
import yaml                     # for reading yaml data easily.
import pyotp                    # to fatch live time TOTP used by shoonya api.
import os                       # to handle system related operations

print(f"Current working diretory is '{os.getcwd()}'. ")
print("Changing directory to root...")
# change current working dir to root
os.chdir("../")
print(f"Now the diretory is '{os.getcwd()}'. ")


# adding src/shoonya/ to path so that we can use shoonya module.
import sys
sys.path.append('src/shoonya/')

from api_helper import ShoonyaApiPy

# COUTION : DO NOT RUN this cell again after running it becouse it changes the path of current working directory.
# Out:
# Current working diretory is 'c:\My Files\Projects\python\algo-artha\notebooks'.
# Changing directory to root...
# Now the diretory is 'c:\My Files\Projects\python\algo-artha'.

# %%
# more libraries 
import datetime as dt 
import time
import warnings
warnings.filterwarnings(action='ignore')

# %% [markdown]
# ### Login method
# create ./config/cred.yaml file in the root folder, the cred.yaml file should contains followings:
# ```yaml
# user    : <user-id>
# pwd     : <password>
# totptoken : <totp - token>
# vc      : <vendor - code>
# apikey  : <api - key>
# imei    : <imei>
# ```
#
# *For more information about shoonya api *[Github Page](https://github.com/Shoonya-Dev/ShoonyaApi-py)*.

# %%
# create a api instance
api = ShoonyaApiPy()

# raed cred.yaml data using yaml file.
with open('config/cred.yml') as f:
    cred = yaml.load(f, Loader=yaml.FullLoader)

# now loaging to api as follows.
ret = api.login(
    userid=cred['user'],
    password=cred['pwd'],
    twoFA=pyotp.TOTP(cred['totptoken']).now(),
    vendor_code=cred['vc'],
    api_secret=cred['apikey'],
    imei=cred['imei']
)

ret
# Out:
# {'request_time': '22:09:55 03-01-2024',
#  'actid': 'FA133525',
#  'access_type': ['WEB', 'TT', 'MOB', 'API'],
#  'uname': 'MOHIT RAJ RATHOR',
#  'prarr': [{'prd': 'C',
#    's_prdt_ali': 'CNC',
#    'exch': ['NSE', 'BSE', 'NIPO', 'BSTAR']},
#   {'prd': 'M',
#    's_prdt_ali': 'NRML',
#    'exch': ['NFO', 'BFO', 'CDS', 'BCD', 'MCX', 'NCX']},
#   {'prd': 'I',
#    's_prdt_ali': 'MIS',
#    'exch': ['NSE', 'BSE', 'NFO', 'BFO', 'CDS', 'BCD', 'MCX', 'NCX']},
#   {'prd': 'H',
#    's_prdt_ali': 'CO',
#    'exch': ['NSE', 'NFO', 'CDS', 'MCX', 'BSE']},
#   {'prd': 'B',
#    's_prdt_ali': 'BO',
#    'exch': ['NSE', 'NFO', 'CDS', 'MCX', 'BSE']}],
#  'exch_prd': [{'exch': 'NSE', 'prds': ['C', 'I', 'H', 'B']},
#   {'exch': 'NIPO', 'prds': ['C']},
#   {'exch': 'NFO', 'prds': ['M', 'I', 'H', 'B']},
#   {'exch': 'CDS', 'prds': ['M', 'I', 'H', 'B']},
#   {'exch': 'BSE', 'prds': ['C', 'I', 'H', 'B']},
#   {'exch': 'BCD', 'prds': ['M', 'I']},
#   {'exch': 'MCX', 'prds': ['M', 'I', 'H', 'B']},
#   {'exch': 'NCX', 'prds': ['M', 'I']},
#   {'exch': 'BSTAR', 'prds': ['C']},
#   {'exch': 'BFO', 'prds': ['M', 'I']}],
#  'stat': 'Ok',
#  'susertoken': 'ce2f17256441b960caf260d29e7a8cb60251eef16c5581c0f690638bbc7f36d2',
#  'email': 'mohitrajrathor@gmail.com',
#  'uid': 'FA133525',
#  'brnchid': 'HO',
#  'totp_set': '1',
#  'm_num': '9462443361',
#  'orarr': ['MKT', 'LMT', 'SL-LMT', 'SL-MKT'],
#  'exarr': ['NSE',
#   'NIPO',
#   'NFO',
#   'CDS',
#   'BSE',
#   'BCD',
#   'MCX',
#   'NCX',
#   'BSTAR',
#   'BFO'],
#  'values': ['1', '2', '3', '4'],
#  'mws': {'1': [{'exch': 'NSE',
#     'token': '26009',
#     'tsym': 'Nifty Bank',
#     'instname': 'UNDIND',
#     'pp': '2',
#     'ls': '1',
#     'ti': '0.05',
#     'nontrd': '1'},
#    {'exch': 'NSE',
#     'token': '26000',
#     'tsym': 'Nifty 50',
#     'instname': 'UNDIND',
#     'pp': '2',
#     'ls': '1',
#     'ti': '0.05',
#     'nontrd': '1'}],
#   '2': [{'exch': 'NSE',
#     'token': '26074',
#     'tsym': 'NIFTY MID SELECT',
#     'instname': 'UNDIND',
#     'pp': '2',
#     'ls': '1',
#     'ti': '0.05',
#     'nontrd': '1'},
#    {'exch': 'NSE',
#     'token': '3045',
#     'tsym': 'SBIN-EQ',
#     'instname': 'EQ',
#     'pp': '2',
#     'ls': '1',
#     'ti': '0.05'}],
#   '3': [{'exch': 'NSE',
#     'token': '9408',
#     'tsym': 'RAINBOW-EQ',
#     'instname': 'EQ',
#     'pp': '2',
#     'ls': '1',
#     'ti': '0.05'},
#    {'exch': 'NSE',
#     'token': '399',
#     'tsym': 'NIACL-EQ',
#     'instname': 'EQ',
#     'pp': '2',
#     'ls': '1',
#     'ti': '0.05'},
#    {'exch': 'NSE',
#     'token': '15283',
#     'tsym': 'KNRCON-EQ',
#     'instname': 'EQ',
#     'pp': '2',
#     'ls': '1',
#     'ti': '0.05'},
#    {'exch': 'NSE',
#     'token': '513',
#     'tsym': 'BOMDYEING-EQ',
#     'instname': 'EQ',
#     'pp': '2',
#     'ls': '1',
#     'ti': '0.05'}],
#   '4': [{'exch': 'NSE',
#     'token': '2859',
#     'tsym': 'RAYMOND-EQ',
#     'instname': 'EQ',
#     'pp': '2',
#     'ls': '1',
#     'ti': '0.05'}]},
#  'brkname': 'FINV',
#  'lastaccesstime': '1704299995'}

# %% [markdown]
# ### View holding detailes

# %%
# to view intraday and option positions.
ret = api.get_positions()
type(ret)

# it show Nonetype if not position is held.
# Out:
# NoneType

# %%
nse_master = pd.read_csv("data/shoonya_masters/NSE_symbols.txt", index_col="Symbol")
nse_master
# Out:
#                    Exchange  Token  LotSize  TradingSymbol Instrument  \
# Symbol
# Nifty 50                NSE  26000        1    NIFTY INDEX      INDEX
# Nifty Bank              NSE  26009        1     NIFTY BANK      INDEX
# INDIAVIX                NSE  26017        1      INDIA VIX      INDEX
# Nifty Fin Services      NSE  26037        1       FINNIFTY      INDEX
# NIFTY MID SELECT        NSE  26074        1     MIDCPNIFTY      INDEX
# ...                     ...    ...      ...            ...        ...
# 051NSETEST              NSE  14758        1  051NSETEST-EQ         EQ
# 041NSETEST              NSE  14755        1  041NSETEST-EQ         EQ
# 031NSETEST              NSE  14753        1  031NSETEST-EQ         EQ
# 021NSETEST              NSE  14751        1  021NSETEST-EQ         EQ
# 011NSETEST              NSE  14747        1  011NSETEST-EQ         EQ
#
#                     TickSize  Unnamed: 7
# Symbol
# Nifty 50                0.00         NaN
# Nifty Bank              0.00         NaN
# INDIAVIX                0.00         NaN
# Nifty Fin Services      0.00         NaN
# NIFTY MID SELECT        0.00         NaN
# ...                      ...         ...
# 051NSETEST              0.05         NaN
# 041NSETEST              0.05         NaN
# 031NSETEST              0.05         NaN
# 021NSETEST              0.05         NaN
# 011NSETEST              0.05         NaN
#
# [6096 rows x 7 columns]

# %%
nse_master.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6096 entries, Nifty 50 to 011NSETEST
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Exchange       6096 non-null   object
#  1   Token          6096 non-null   int64
#  2   LotSize        6096 non-null   int64
#  3   TradingSymbol  6096 non-null   object
#  4   Instrument     6081 non-null   object
#  5   TickSize       6096 non-null   float64
#  6   Unnamed: 7     0 non-null      float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 381.0+ KB

# %%
nifty_200 = pd.read_csv("data/nifty_200.csv")['Symbol'].to_list()
nifty_200
# Out:
# ['ABB',
#  'ACC',
#  'APLAPOLLO',
#  'AUBANK',
#  'ADANIENSOL',
#  'ADANIENT',
#  'ADANIGREEN',
#  'ADANIPORTS',
#  'ADANIPOWER',
#  'ATGL',
#  'AWL',
#  'ABCAPITAL',
#  'ABFRL',
#  'ALKEM',
#  'AMBUJACEM',
#  'APOLLOHOSP',
#  'APOLLOTYRE',
#  'ASHOKLEY',
#  'ASIANPAINT',
#  'ASTRAL',
#  'AUROPHARMA',
#  'DMART',
#  'AXISBANK',
#  'BAJAJ-AUTO',
#  'BAJFINANCE',
#  'BAJAJFINSV',
#  'BAJAJHLDNG',
#  'BALKRISIND',
#  'BANDHANBNK',
#  'BANKBARODA',
#  'BANKINDIA',
#  'BATAINDIA',
#  'BERGEPAINT',
#  'BDL',
#  'BEL',
#  'BHARATFORG',
#  'BHEL',
#  'BPCL',
#  'BHARTIARTL',
#  'BIOCON',
#  'BOSCHLTD',
#  'BRITANNIA',
#  'CGPOWER',
#  'CANBK',
#  'CHOLAFIN',
#  'CIPLA',
#  'COALINDIA',
#  'COFORGE',
#  'COLPAL',
#  'CONCOR',
#  'COROMANDEL',
#  'CROMPTON',
#  'CUMMINSIND',
#  'DLF',
#  'DABUR',
#  'DALBHARAT',
#  'DEEPAKNTR',
#  'DELHIVERY',
#  'DEVYANI',
#  'DIVISLAB',
#  'DIXON',
#  'LALPATHLAB',
#  'DRREDDY',
#  'EICHERMOT',
#  'ESCORTS',
#  'NYKAA',
#  'FEDERALBNK',
#  'FACT',
#  'FORTIS',
#  'GAIL',
#  'GLAND',
#  'GODREJCP',
#  'GODREJPROP',
#  'GRASIM',
#  'FLUOROCHEM',
#  'GUJGASLTD',
#  'HCLTECH',
#  'HDFCAMC',
#  'HDFCBANK',
#  'HDFCLIFE',
#  'HAVELLS',
#  'HEROMOTOCO',
#  'HINDALCO',
#  'HAL',
#  'HINDPETRO',
#  'HINDUNILVR',
#  'ICICIBANK',
#  'ICICIGI',
#  'ICICIPRULI',
#  'IDFCFIRSTB',
#  'ITC',
#  'INDIANB',
#  'INDHOTEL',
#  'IOC',
#  'IRCTC',
#  'IRFC',
#  'IGL',
#  'INDUSTOWER',
#  'INDUSINDBK',
#  'NAUKRI',
#  'INFY',
#  'INDIGO',
#  'IPCALAB',
#  'JSWENERGY',
#  'JSWSTEEL',
#  'JINDALSTEL',
#  'JUBLFOOD',
#  'KPITTECH',
#  'KOTAKBANK',
#  'L&TFH',
#  'LTTS',
#  'LICHSGFIN',
#  'LTIM',
#  'LT',
#  'LAURUSLABS',
#  'LICI',
#  'LUPIN',
#  'MRF',
#  'LODHA',
#  'M&MFIN',
#  'M&M',
#  'MANKIND',
#  'MARICO',
#  'MARUTI',
#  'MFSL',
#  'MAXHEALTH',
#  'MAZDOCK',
#  'MSUMI',
#  'MPHASIS',
#  'MUTHOOTFIN',
#  'NHPC',
#  'NMDC',
#  'NTPC',
#  'NAVINFLUOR',
#  'NESTLEIND',
#  'OBEROIRLTY',
#  'ONGC',
#  'OIL',
#  'PAYTM',
#  'POLICYBZR',
#  'PIIND',
#  'PAGEIND',
#  'PATANJALI',
#  'PERSISTENT',
#  'PETRONET',
#  'PIDILITIND',
#  'PEL',
#  'POLYCAB',
#  'POONAWALLA',
#  'PFC',
#  'POWERGRID',
#  'PRESTIGE',
#  'PGHH',
#  'PNB',
#  'RECLTD',
#  'RVNL',
#  'RELIANCE',
#  'SBICARD',
#  'SBILIFE',
#  'SRF',
#  'MOTHERSON',
#  'SHREECEM',
#  'SHRIRAMFIN',
#  'SIEMENS',
#  'SONACOMS',
#  'SBIN',
#  'SAIL',
#  'SUNPHARMA',
#  'SUNTV',
#  'SYNGENE',
#  'TVSMOTOR',
#  'TATACHEM',
#  'TATACOMM',
#  'TCS',
#  'TATACONSUM',
#  'TATAELXSI',
#  'TATAMTRDVR',
#  'TATAMOTORS',
#  'TATAPOWER',
#  'TATASTEEL',
#  'TECHM',
#  'RAMCOCEM',
#  'TITAN',
#  'TORNTPHARM',
#  'TORNTPOWER',
#  'TRENT',
#  'TIINDIA',
#  'UPL',
#  'ULTRACEMCO',
#  'UNIONBANK',
#  'UBL',
#  'MCDOWELL-N',
#  'VBL',
#  'VEDL',
#  'IDEA',
#  'VOLTAS',
#  'WIPRO',
#  'YESBANK',
#  'ZEEL',
#  'ZOMATO',
#  'ZYDUSLIFE']

# %%
start_time = (dt.datetime.now() - dt.timedelta(days=5)).timestamp()

ret = api.get_time_price_series(exchange="NSE", token=str(nse_master['Token'].loc['SBIN']), starttime=start_time, interval="5")
ret
# Out:
# [{'stat': 'Ok',
#   'time': '03-01-2024 15:25:00',
#   'ssboe': '1704275700',
#   'into': '643.40',
#   'inth': '644.90',
#   'intl': '643.20',
#   'intc': '644.50',
#   'intvwap': '644.44',
#   'intv': '231881',
#   'intoi': '0',
#   'v': '14566503',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '03-01-2024 15:20:00',
#   'ssboe': '1704275400',
#   'into': '643.30',
#   'inth': '643.90',
#   'intl': '643.05',
#   'intc': '643.45',
#   'intvwap': '643.19',
#   'intv': '307069',
#   'intoi': '0',
#   'v': '14334622',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '03-01-2024 15:15:00',
#   'ssboe': '1704275100',
#   'into': '643.95',
#   'inth': '643.95',
#   'intl': '643.00',
#   'intc': '643.25',
#   'intvwap': '643.63',
#   'intv': '305953',
#   'intoi': '0',
#   'v': '14027553',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '03-01-2024 15:10:00',
#   'ssboe': '1704274800',
#   'into': '643.45',
#   'inth': '644.25',
#   'intl': '643.20',
#   'intc': '643.75',
#   'intvwap': '643.69',
#   'intv': '262946',
#   'intoi': '0',
#   'v': '13721600',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '03-01-2024 15:05:00',
#   'ssboe': '1704274500',
#   'into': '643.35',
#   'inth': '643.90',
#   'intl': '642.90',
#   'intc': '643.50',
#   'intvwap': '643.17',
#   'intv': '262319',
#   'intoi': '0',
#   'v': '13458654',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '03-01-2024 15:00:00',
#   'ssboe': '1704274200',
#   'into': '643.45',
#   'inth': '643.65',
#   'intl': '642.15',
#   'intc': '643.40',
#   'intvwap': '643.16',
#   'intv': '525227',
#   'intoi': '0',
#   'v': '13196335',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '03-01-2024 14:55:00',
#   'ssboe': '1704273900',
#   'into': '643.40',
#   'inth': '643.80',
#   'intl': '643.05',
#   'intc': '643.40',
#   'intvwap': '643.17',
#   'intv': '160539',
#   'intoi': '0',
#   'v': '12671108',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '03-01-2024 14:50:00',
#   'ssboe': '1704273600',
#   'into': '642.80',
#   'inth': '643.70',
#   'intl': '642.55',
#   'intc': '643.30',
#   'intvwap': '643.17',
#   'intv': '139070',
#   'intoi': '0',
#   'v': '12510569',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '03-01-2024 14:45:00',
#   'ssboe': '1704273300',
#   'into': '643.20',
#   'inth': '643.95',
#   'intl': '642.60',
#   'intc': '642.75',
#   'intvwap': '643.17',
#   'intv': '118929',
#   'intoi': '0',
#   'v': '12371499',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '03-01-2024 14:40:00',
#   'ssboe': '1704273000',
#   'into': '643.35',
#   'inth': '644.10',
#   'intl': '643.20',
#   'intc': '643.30',
#   'intvwap': '644.09',
#   'intv': '131415',
#   'intoi': '0',
#   'v': '12252570',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '03-01-2024 14:35:00',
#   'ssboe': '1704272700',
#   'into': '643.95',
#   'inth': '644.30',
#   'intl': '643.20',
#   'intc': '643.30',
#   'intvwap': '643.90',
#   'intv': '159902',
#   'intoi': '0',
#   'v': '12121155',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '03-01-2024 14:30:00',
#   'ssboe': '1704272400',
#   'into': '644.15',
#   'inth': '644.50',
#   'intl': '643.80',
#   'intc': '643.90',
#   'intvwap': '644.20',
#   'intv': '112161',
#   'intoi': '0',
#   'v': '11961253',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '03-01-2024 14:25:00',
#   'ssboe': '1704272100',
#   'into': '644.20',
#   'inth': '644.45',
#   'intl': '643.20',
#   'intc': '644.00',
#   'intvwap': '643.61',
#   'intv': '244625',
#   'intoi': '0',
#   'v': '11849092',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '03-01-2024 14:20:00',
#   'ssboe': '1704271800',
#   'into': '643.85',
#   'inth': '644.60',
#   'intl': '643.70',
#   'intc': '644.25',
#   'intvwap': '644.59',
#   'intv': '78476',
#   'intoi': '0',
#   'v': '11604467',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '03-01-2024 14:15:00',
#   'ssboe': '1704271500',
#   'into': '645.30',
#   'inth': '645.40',
#   'intl': '643.85',
#   'intc': '643.90',
#   'intvwap': '644.43',
#   'intv': '86800',
#   'intoi': '0',
#   'v': '11525991',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '03-01-2024 14:10:00',
#   'ssboe': '1704271200',
#   'into': '645.70',
#   'inth': '646.30',
#   'intl': '645.15',
#   'intc': '645.45',
#   'intvwap': '645.13',
#   'intv': '111654',
#   'intoi': '0',
#   'v': '11439191',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '03-01-2024 14:05:00',
#   'ssboe': '1704270900',
#   'into': '644.65',
#   'inth': '645.80',
#   'intl': '644.45',
#   'intc': '645.65',
#   'intvwap': '644.92',
#   'intv': '181878',
#   'intoi': '0',
#   'v': '11327537',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '03-01-2024 14:00:00',
#   'ssboe': '1704270600',
#   'into': '645.00',
#   'inth': '645.30',
#   'intl': '644.25',
#   'intc': '644.85',
#   'intvwap': '644.93',
#   'intv': '175230',
#   'intoi': '0',
#   'v': '11145659',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '03-01-2024 13:55:00',
#   'ssboe': '1704270300',
#   'into': '644.90',
#   'inth': '645.50',
#   'intl': '644.30',
#   'intc': '644.85',
#   'intvwap': '644.68',
#   'intv': '258013',
#   'intoi': '0',
#   'v': '10970429',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '03-01-2024 13:50:00',
#   'ssboe': '1704270000',
#   'into': '645.25',
#   'inth': '645.25',
#   'intl': '644.60',
#   'intc': '644.75',
#   'intvwap': '644.79',
#   'intv': '117080',
#   'intoi': '0',
#   'v': '10712416',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '03-01-2024 13:45:00',
#   'ssboe': '1704269700',
#   'into': '645.25',
#   'inth': '645.50',
#   'intl': '644.60',
#   'intc': '645.00',
#   'intvwap': '645.28',
#   'intv': '90658',
#   'intoi': '0',
#   'v': '10595336',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '03-01-2024 13:40:00',
#   'ssboe': '1704269400',
#   'into': '645.60',
#   'inth': '646.00',
#   'intl': '645.20',
#   'intc': '645.20',
#   'intvwap': '645.82',
#   'intv': '108565',
#   'intoi': '0',
#   'v': '10504678',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '03-01-2024 13:35:00',
#   'ssboe': '1704269100',
#   'into': '645.45',
#   'inth': '645.90',
#   'intl': '644.85',
#   'intc': '645.75',
#   'intvwap': '645.60',
#   'intv': '114792',
#   'intoi': '0',
#   'v': '10396113',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '03-01-2024 13:30:00',
#   'ssboe': '1704268800',
#   'into': '646.20',
#   'inth': '646.45',
#   'intl': '644.80',
#   'intc': '645.10',
#   'intvwap': '644.73',
#   'intv': '110419',
#   'intoi': '0',
#   'v': '10281321',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '03-01-2024 13:25:00',
#   'ssboe': '1704268500',
#   'into': '646.20',
#   'inth': '646.45',
#   'intl': '645.50',
#   'intc': '646.05',
#   'intvwap': '646.63',
#   'intv': '106718',
#   'intoi': '0',
#   'v': '10170902',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '03-01-2024 13:20:00',
#   'ssboe': '1704268200',
#   'into': '646.10',
#   'inth': '646.50',
#   'intl': '645.55',
#   'intc': '646.30',
#   'intvwap': '645.78',
#   'intv': '200170',
#   'intoi': '0',
#   'v': '10064184',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '03-01-2024 13:15:00',
#   'ssboe': '1704267900',
#   'into': '646.15',
#   'inth': '647.00',
#   'intl': '645.55',
#   'intc': '645.95',
#   'intvwap': '646.18',
#   'intv': '170215',
#   'intoi': '0',
#   'v': '9864014',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '03-01-2024 13:10:00',
#   'ssboe': '1704267600',
#   'into': '646.20',
#   'inth': '646.45',
#   'intl': '645.60',
#   'intc': '646.05',
#   'intvwap': '646.05',
#   'intv': '142776',
#   'intoi': '0',
#   'v': '9693799',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '03-01-2024 13:05:00',
#   'ssboe': '1704267300',
#   'into': '645.25',
#   'inth': '646.55',
#   'intl': '645.20',
#   'intc': '646.25',
#   'intvwap': '645.74',
#   'intv': '122139',
#   'intoi': '0',
#   'v': '9551023',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '03-01-2024 13:00:00',
#   'ssboe': '1704267000',
#   'into': '644.25',
#   'inth': '645.40',
#   'intl': '644.15',
#   'intc': '645.40',
#   'intvwap': '645.15',
#   'intv': '110457',
#   'intoi': '0',
#   'v': '9428884',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '03-01-2024 12:55:00',
#   'ssboe': '1704266700',
#   'into': '644.25',
#   'inth': '644.65',
#   'intl': '644.05',
#   'intc': '644.30',
#   'intvwap': '643.77',
#   'intv': '78010',
#   'intoi': '0',
#   'v': '9318427',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '03-01-2024 12:50:00',
#   'ssboe': '1704266400',
#   'into': '644.40',
#   'inth': '644.70',
#   'intl': '644.10',
#   'intc': '644.10',
#   'intvwap': '644.55',
#   'intv': '183262',
#   'intoi': '0',
#   'v': '9240417',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '03-01-2024 12:45:00',
#   'ssboe': '1704266100',
#   'into': '643.20',
#   'inth': '644.35',
#   'intl': '643.10',
#   'intc': '644.35',
#   'intvwap': '643.92',
#   'intv': '128380',
#   'intoi': '0',
#   'v': '9057155',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '03-01-2024 12:40:00',
#   'ssboe': '1704265800',
#   'into': '643.40',
#   'inth': '643.40',
#   'intl': '642.60',
#   'intc': '643.10',
#   'intvwap': '642.52',
#   'intv': '85284',
#   'intoi': '0',
#   'v': '8928775',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '03-01-2024 12:35:00',
#   'ssboe': '1704265500',
#   'into': '643.20',
#   'inth': '643.55',
#   'intl': '642.50',
#   'intc': '643.35',
#   'intvwap': '642.52',
#   'intv': '78789',
#   'intoi': '0',
#   'v': '8843491',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '03-01-2024 12:30:00',
#   'ssboe': '1704265200',
#   'into': '642.80',
#   'inth': '643.80',
#   'intl': '642.25',
#   'intc': '643.15',
#   'intvwap': '643.12',
#   'intv': '141484',
#   'intoi': '0',
#   'v': '8764702',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '03-01-2024 12:25:00',
#   'ssboe': '1704264900',
#   'into': '643.70',
#   'inth': '643.75',
#   'intl': '641.30',
#   'intc': '642.70',
#   'intvwap': '642.50',
#   'intv': '224877',
#   'intoi': '0',
#   'v': '8623218',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '03-01-2024 12:20:00',
#   'ssboe': '1704264600',
#   'into': '645.30',
#   'inth': '645.30',
#   'intl': '642.85',
#   'intc': '643.75',
#   'intvwap': '643.45',
#   'intv': '340770',
#   'intoi': '0',
#   'v': '8398341',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '03-01-2024 12:15:00',
#   'ssboe': '1704264300',
#   'into': '645.30',
#   'inth': '645.95',
#   'intl': '645.05',
#   'intc': '645.10',
#   'intvwap': '645.45',
#   'intv': '80035',
#   'intoi': '0',
#   'v': '8057571',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '03-01-2024 12:10:00',
#   'ssboe': '1704264000',
#   'into': '645.55',
#   'inth': '645.75',
#   'intl': '645.05',
#   'intc': '645.45',
#   'intvwap': '645.76',
#   'intv': '141170',
#   'intoi': '0',
#   'v': '7977536',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '03-01-2024 12:05:00',
#   'ssboe': '1704263700',
#   'into': '647.20',
#   'inth': '647.55',
#   'intl': '645.05',
#   'intc': '645.70',
#   'intvwap': '646.16',
#   'intv': '336743',
#   'intoi': '0',
#   'v': '7836366',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '03-01-2024 12:00:00',
#   'ssboe': '1704263400',
#   'into': '646.60',
#   'inth': '647.95',
#   'intl': '646.10',
#   'intc': '647.25',
#   'intvwap': '647.36',
#   'intv': '346446',
#   'intoi': '0',
#   'v': '7499623',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '03-01-2024 11:55:00',
#   'ssboe': '1704263100',
#   'into': '646.95',
#   'inth': '647.15',
#   'intl': '646.50',
#   'intc': '646.65',
#   'intvwap': '646.35',
#   'intv': '112060',
#   'intoi': '0',
#   'v': '7153177',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '03-01-2024 11:50:00',
#   'ssboe': '1704262800',
#   'into': '647.00',
#   'inth': '647.20',
#   'intl': '646.50',
#   'intc': '646.90',
#   'intvwap': '647.24',
#   'intv': '129066',
#   'intoi': '0',
#   'v': '7041117',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '03-01-2024 11:45:00',
#   'ssboe': '1704262500',
#   'into': '646.95',
#   'inth': '647.40',
#   'intl': '646.35',
#   'intc': '647.10',
#   'intvwap': '646.93',
#   'intv': '195839',
#   'intoi': '0',
#   'v': '6912051',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '03-01-2024 11:40:00',
#   'ssboe': '1704262200',
#   'into': '644.90',
#   'inth': '647.40',
#   'intl': '644.85',
#   'intc': '646.90',
#   'intvwap': '646.45',
#   'intv': '305801',
#   'intoi': '0',
#   'v': '6716212',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '03-01-2024 11:35:00',
#   'ssboe': '1704261900',
#   'into': '644.25',
#   'inth': '645.10',
#   'intl': '644.25',
#   'intc': '644.95',
#   'intvwap': '644.82',
#   'intv': '92438',
#   'intoi': '0',
#   'v': '6410411',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '03-01-2024 11:30:00',
#   'ssboe': '1704261600',
#   'into': '644.65',
#   'inth': '645.00',
#   'intl': '643.85',
#   'intc': '644.45',
#   'intvwap': '644.08',
#   'intv': '135814',
#   'intoi': '0',
#   'v': '6317973',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '03-01-2024 11:25:00',
#   'ssboe': '1704261300',
#   'into': '646.00',
#   'inth': '646.10',
#   'intl': '644.50',
#   'intc': '644.70',
#   'intvwap': '645.64',
#   'intv': '152344',
#   'intoi': '0',
#   'v': '6182159',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '03-01-2024 11:20:00',
#   'ssboe': '1704261000',
#   'into': '646.05',
#   'inth': '646.25',
#   'intl': '645.55',
#   'intc': '645.85',
#   'intvwap': '645.86',
#   'intv': '126310',
#   'intoi': '0',
#   'v': '6029815',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '03-01-2024 11:15:00',
#   'ssboe': '1704260700',
#   'into': '644.90',
#   'inth': '646.30',
#   'intl': '644.90',
#   'intc': '646.15',
#   'intvwap': '645.68',
#   'intv': '257599',
#   'intoi': '0',
#   'v': '5903505',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '03-01-2024 11:10:00',
#   'ssboe': '1704260400',
#   'into': '644.80',
#   'inth': '646.45',
#   'intl': '644.50',
#   'intc': '645.00',
#   'intvwap': '645.49',
#   'intv': '300749',
#   'intoi': '0',
#   'v': '5645906',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '03-01-2024 11:05:00',
#   'ssboe': '1704260100',
#   'into': '644.35',
#   'inth': '644.95',
#   'intl': '643.65',
#   'intc': '644.85',
#   'intvwap': '644.37',
#   'intv': '151926',
#   'intoi': '0',
#   'v': '5345157',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '03-01-2024 11:00:00',
#   'ssboe': '1704259800',
#   'into': '643.40',
#   'inth': '644.95',
#   'intl': '643.10',
#   'intc': '644.50',
#   'intvwap': '643.66',
#   'intv': '159173',
#   'intoi': '0',
#   'v': '5193231',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '03-01-2024 10:55:00',
#   'ssboe': '1704259500',
#   'into': '643.00',
#   'inth': '645.30',
#   'intl': '642.90',
#   'intc': '643.45',
#   'intvwap': '644.30',
#   'intv': '347843',
#   'intoi': '0',
#   'v': '5034058',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '03-01-2024 10:50:00',
#   'ssboe': '1704259200',
#   'into': '642.70',
#   'inth': '643.20',
#   'intl': '642.35',
#   'intc': '642.95',
#   'intvwap': '642.78',
#   'intv': '103050',
#   'intoi': '0',
#   'v': '4686215',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '03-01-2024 10:45:00',
#   'ssboe': '1704258900',
#   'into': '643.15',
#   'inth': '643.80',
#   'intl': '642.70',
#   'intc': '642.80',
#   'intvwap': '643.24',
#   'intv': '139137',
#   'intoi': '0',
#   'v': '4583165',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '03-01-2024 10:40:00',
#   'ssboe': '1704258600',
#   'into': '643.45',
#   'inth': '643.45',
#   'intl': '641.80',
#   'intc': '643.25',
#   'intvwap': '642.65',
#   'intv': '188771',
#   'intoi': '0',
#   'v': '4444028',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '03-01-2024 10:35:00',
#   'ssboe': '1704258300',
#   'into': '644.40',
#   'inth': '644.45',
#   'intl': '643.05',
#   'intc': '643.25',
#   'intvwap': '643.70',
#   'intv': '268167',
#   'intoi': '0',
#   'v': '4255257',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '03-01-2024 10:30:00',
#   'ssboe': '1704258000',
#   'into': '640.95',
#   'inth': '644.90',
#   'intl': '640.70',
#   'intc': '644.50',
#   'intvwap': '643.16',
#   'intv': '718750',
#   'intoi': '0',
#   'v': '3987090',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '03-01-2024 10:25:00',
#   'ssboe': '1704257700',
#   'into': '638.95',
#   'inth': '641.45',
#   'intl': '638.80',
#   'intc': '641.00',
#   'intvwap': '640.13',
#   'intv': '365626',
#   'intoi': '0',
#   'v': '3268340',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '03-01-2024 10:20:00',
#   'ssboe': '1704257400',
#   'into': '639.60',
#   'inth': '639.60',
#   'intl': '638.35',
#   'intc': '639.05',
#   'intvwap': '639.08',
#   'intv': '120095',
#   'intoi': '0',
#   'v': '2902714',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '03-01-2024 10:15:00',
#   'ssboe': '1704257100',
#   'into': '639.00',
#   'inth': '639.95',
#   'intl': '638.60',
#   'intc': '639.65',
#   'intvwap': '639.34',
#   'intv': '174778',
#   'intoi': '0',
#   'v': '2782619',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '03-01-2024 10:10:00',
#   'ssboe': '1704256800',
#   'into': '638.50',
#   'inth': '639.10',
#   'intl': '637.90',
#   'intc': '639.10',
#   'intvwap': '638.54',
#   'intv': '132522',
#   'intoi': '0',
#   'v': '2607841',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '03-01-2024 10:05:00',
#   'ssboe': '1704256500',
#   'into': '638.50',
#   'inth': '638.75',
#   'intl': '637.35',
#   'intc': '638.40',
#   'intvwap': '638.01',
#   'intv': '173299',
#   'intoi': '0',
#   'v': '2475319',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '03-01-2024 10:00:00',
#   'ssboe': '1704256200',
#   'into': '638.55',
#   'inth': '639.10',
#   'intl': '637.35',
#   'intc': '638.65',
#   'intvwap': '638.30',
#   'intv': '152828',
#   'intoi': '0',
#   'v': '2302020',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '03-01-2024 09:55:00',
#   'ssboe': '1704255900',
#   'into': '637.70',
#   'inth': '638.70',
#   'intl': '637.65',
#   'intc': '638.60',
#   'intvwap': '638.06',
#   'intv': '113117',
#   'intoi': '0',
#   'v': '2149192',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '03-01-2024 09:50:00',
#   'ssboe': '1704255600',
#   'into': '637.85',
#   'inth': '638.40',
#   'intl': '637.40',
#   'intc': '638.00',
#   'intvwap': '637.94',
#   'intv': '137321',
#   'intoi': '0',
#   'v': '2036075',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '03-01-2024 09:45:00',
#   'ssboe': '1704255300',
#   'into': '637.25',
#   'inth': '638.30',
#   'intl': '636.95',
#   'intc': '637.95',
#   'intvwap': '637.48',
#   'intv': '173123',
#   'intoi': '0',
#   'v': '1898754',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '03-01-2024 09:40:00',
#   'ssboe': '1704255000',
#   'into': '638.20',
#   'inth': '638.80',
#   'intl': '636.85',
#   'intc': '637.30',
#   'intvwap': '637.74',
#   'intv': '200988',
#   'intoi': '0',
#   'v': '1725631',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '03-01-2024 09:35:00',
#   'ssboe': '1704254700',
#   'into': '639.80',
#   'inth': '640.00',
#   'intl': '637.80',
#   'intc': '638.05',
#   'intvwap': '638.87',
#   'intv': '192253',
#   'intoi': '0',
#   'v': '1524643',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '03-01-2024 09:30:00',
#   'ssboe': '1704254400',
#   'into': '641.30',
#   'inth': '641.45',
#   'intl': '639.65',
#   'intc': '639.75',
#   'intvwap': '640.72',
#   'intv': '265508',
#   'intoi': '0',
#   'v': '1332390',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '03-01-2024 09:25:00',
#   'ssboe': '1704254100',
#   'into': '638.25',
#   'inth': '641.30',
#   'intl': '638.15',
#   'intc': '641.10',
#   'intvwap': '639.54',
#   'intv': '282218',
#   'intoi': '0',
#   'v': '1066882',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '03-01-2024 09:20:00',
#   'ssboe': '1704253800',
#   'into': '638.55',
#   'inth': '639.70',
#   'intl': '637.75',
#   'intc': '638.30',
#   'intvwap': '638.63',
#   'intv': '266843',
#   'intoi': '0',
#   'v': '784664',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '03-01-2024 09:15:00',
#   'ssboe': '1704253500',
#   'into': '638.40',
#   'inth': '639.00',
#   'intl': '636.05',
#   'intc': '638.65',
#   'intvwap': '637.84',
#   'intv': '499093',
#   'intoi': '0',
#   'v': '517821',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '02-01-2024 15:25:00',
#   'ssboe': '1704189300',
#   'into': '639.20',
#   'inth': '639.55',
#   'intl': '638.50',
#   'intc': '639.35',
#   'intvwap': '639.16',
#   'intv': '230330',
#   'intoi': '0',
#   'v': '18728',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '02-01-2024 15:20:00',
#   'ssboe': '1704189000',
#   'into': '639.55',
#   'inth': '639.75',
#   'intl': '638.40',
#   'intc': '639.10',
#   'intvwap': '638.97',
#   'intv': '387302',
#   'intoi': '0',
#   'v': '14928512',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '02-01-2024 15:15:00',
#   'ssboe': '1704188700',
#   'into': '639.30',
#   'inth': '639.85',
#   'intl': '638.80',
#   'intc': '639.35',
#   'intvwap': '639.26',
#   'intv': '450032',
#   'intoi': '0',
#   'v': '14541210',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '02-01-2024 15:10:00',
#   'ssboe': '1704188400',
#   'into': '638.15',
#   'inth': '639.80',
#   'intl': '637.45',
#   'intc': '639.50',
#   'intvwap': '638.53',
#   'intv': '471101',
#   'intoi': '0',
#   'v': '14091178',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '02-01-2024 15:05:00',
#   'ssboe': '1704188100',
#   'into': '641.10',
#   'inth': '641.35',
#   'intl': '637.80',
#   'intc': '638.30',
#   'intvwap': '639.63',
#   'intv': '530638',
#   'intoi': '0',
#   'v': '13620077',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '02-01-2024 15:00:00',
#   'ssboe': '1704187800',
#   'into': '641.10',
#   'inth': '641.55',
#   'intl': '640.80',
#   'intc': '641.05',
#   'intvwap': '641.32',
#   'intv': '383697',
#   'intoi': '0',
#   'v': '13089439',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '02-01-2024 14:55:00',
#   'ssboe': '1704187500',
#   'into': '641.45',
#   'inth': '641.85',
#   'intl': '640.65',
#   'intc': '641.25',
#   'intvwap': '641.09',
#   'intv': '281437',
#   'intoi': '0',
#   'v': '12705742',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '02-01-2024 14:50:00',
#   'ssboe': '1704187200',
#   'into': '641.90',
#   'inth': '642.10',
#   'intl': '641.15',
#   'intc': '641.40',
#   'intvwap': '641.63',
#   'intv': '244316',
#   'intoi': '0',
#   'v': '12424305',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '02-01-2024 14:45:00',
#   'ssboe': '1704186900',
#   'into': '641.70',
#   'inth': '642.50',
#   'intl': '641.70',
#   'intc': '642.00',
#   'intvwap': '642.13',
#   'intv': '235701',
#   'intoi': '0',
#   'v': '12179989',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '02-01-2024 14:40:00',
#   'ssboe': '1704186600',
#   'into': '642.80',
#   'inth': '643.45',
#   'intl': '641.50',
#   'intc': '641.75',
#   'intvwap': '642.26',
#   'intv': '209775',
#   'intoi': '0',
#   'v': '11944288',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '02-01-2024 14:35:00',
#   'ssboe': '1704186300',
#   'into': '642.60',
#   'inth': '642.90',
#   'intl': '642.30',
#   'intc': '642.75',
#   'intvwap': '642.82',
#   'intv': '102516',
#   'intoi': '0',
#   'v': '11734513',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '02-01-2024 14:30:00',
#   'ssboe': '1704186000',
#   'into': '641.85',
#   'inth': '642.85',
#   'intl': '641.85',
#   'intc': '642.65',
#   'intvwap': '641.66',
#   'intv': '102311',
#   'intoi': '0',
#   'v': '11631997',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '02-01-2024 14:25:00',
#   'ssboe': '1704185700',
#   'into': '641.75',
#   'inth': '642.00',
#   'intl': '641.45',
#   'intc': '642.00',
#   'intvwap': '642.84',
#   'intv': '49607',
#   'intoi': '0',
#   'v': '11529686',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '02-01-2024 14:20:00',
#   'ssboe': '1704185400',
#   'into': '641.50',
#   'inth': '641.95',
#   'intl': '641.30',
#   'intc': '641.80',
#   'intvwap': '642.33',
#   'intv': '62786',
#   'intoi': '0',
#   'v': '11480079',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '02-01-2024 14:15:00',
#   'ssboe': '1704185100',
#   'into': '642.55',
#   'inth': '642.70',
#   'intl': '641.25',
#   'intc': '641.30',
#   'intvwap': '641.45',
#   'intv': '119818',
#   'intoi': '0',
#   'v': '11417293',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '02-01-2024 14:10:00',
#   'ssboe': '1704184800',
#   'into': '641.75',
#   'inth': '642.90',
#   'intl': '641.75',
#   'intc': '642.60',
#   'intvwap': '642.35',
#   'intv': '120106',
#   'intoi': '0',
#   'v': '11297475',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '02-01-2024 14:05:00',
#   'ssboe': '1704184500',
#   'into': '641.30',
#   'inth': '642.00',
#   'intl': '641.20',
#   'intc': '641.80',
#   'intvwap': '642.39',
#   'intv': '57872',
#   'intoi': '0',
#   'v': '11177369',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '02-01-2024 14:00:00',
#   'ssboe': '1704184200',
#   'into': '642.00',
#   'inth': '642.00',
#   'intl': '640.70',
#   'intc': '641.45',
#   'intvwap': '641.74',
#   'intv': '86371',
#   'intoi': '0',
#   'v': '11119497',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '02-01-2024 13:55:00',
#   'ssboe': '1704183900',
#   'into': '641.90',
#   'inth': '642.00',
#   'intl': '641.45',
#   'intc': '641.80',
#   'intvwap': '641.92',
#   'intv': '74589',
#   'intoi': '0',
#   'v': '11033126',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '02-01-2024 13:50:00',
#   'ssboe': '1704183600',
#   'into': '642.10',
#   'inth': '642.45',
#   'intl': '641.55',
#   'intc': '642.00',
#   'intvwap': '642.15',
#   'intv': '63798',
#   'intoi': '0',
#   'v': '10958537',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '02-01-2024 13:45:00',
#   'ssboe': '1704183300',
#   'into': '641.95',
#   'inth': '642.10',
#   'intl': '641.30',
#   'intc': '642.05',
#   'intvwap': '641.17',
#   'intv': '146865',
#   'intoi': '0',
#   'v': '10894739',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '02-01-2024 13:40:00',
#   'ssboe': '1704183000',
#   'into': '642.00',
#   'inth': '642.35',
#   'intl': '641.50',
#   'intc': '641.85',
#   'intvwap': '641.42',
#   'intv': '106228',
#   'intoi': '0',
#   'v': '10747874',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '02-01-2024 13:35:00',
#   'ssboe': '1704182700',
#   'into': '643.10',
#   'inth': '643.30',
#   'intl': '641.80',
#   'intc': '641.95',
#   'intvwap': '642.72',
#   'intv': '136487',
#   'intoi': '0',
#   'v': '10641646',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '02-01-2024 13:30:00',
#   'ssboe': '1704182400',
#   'into': '642.20',
#   'inth': '643.40',
#   'intl': '641.75',
#   'intc': '643.20',
#   'intvwap': '642.63',
#   'intv': '183754',
#   'intoi': '0',
#   'v': '10505159',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '02-01-2024 13:25:00',
#   'ssboe': '1704182100',
#   'into': '641.20',
#   'inth': '642.20',
#   'intl': '640.85',
#   'intc': '642.05',
#   'intvwap': '641.21',
#   'intv': '117270',
#   'intoi': '0',
#   'v': '10321405',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '02-01-2024 13:20:00',
#   'ssboe': '1704181800',
#   'into': '641.00',
#   'inth': '641.40',
#   'intl': '640.15',
#   'intc': '641.10',
#   'intvwap': '640.34',
#   'intv': '85454',
#   'intoi': '0',
#   'v': '10204135',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '02-01-2024 13:15:00',
#   'ssboe': '1704181500',
#   'into': '640.95',
#   'inth': '641.25',
#   'intl': '640.65',
#   'intc': '641.05',
#   'intvwap': '640.34',
#   'intv': '62226',
#   'intoi': '0',
#   'v': '10118681',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '02-01-2024 13:10:00',
#   'ssboe': '1704181200',
#   'into': '641.30',
#   'inth': '641.45',
#   'intl': '640.55',
#   'intc': '640.90',
#   'intvwap': '642.23',
#   'intv': '52675',
#   'intoi': '0',
#   'v': '10056455',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '02-01-2024 13:05:00',
#   'ssboe': '1704180900',
#   'into': '639.75',
#   'inth': '641.45',
#   'intl': '639.75',
#   'intc': '641.20',
#   'intvwap': '640.33',
#   'intv': '94765',
#   'intoi': '0',
#   'v': '10003780',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '02-01-2024 13:00:00',
#   'ssboe': '1704180600',
#   'into': '641.90',
#   'inth': '642.05',
#   'intl': '639.30',
#   'intc': '639.85',
#   'intvwap': '640.33',
#   'intv': '178391',
#   'intoi': '0',
#   'v': '9909015',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '02-01-2024 12:55:00',
#   'ssboe': '1704180300',
#   'into': '642.50',
#   'inth': '642.80',
#   'intl': '641.70',
#   'intc': '641.85',
#   'intvwap': '642.36',
#   'intv': '186636',
#   'intoi': '0',
#   'v': '9730624',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '02-01-2024 12:50:00',
#   'ssboe': '1704180000',
#   'into': '642.05',
#   'inth': '642.95',
#   'intl': '642.00',
#   'intc': '642.55',
#   'intvwap': '642.36',
#   'intv': '90920',
#   'intoi': '0',
#   'v': '9543988',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '02-01-2024 12:45:00',
#   'ssboe': '1704179700',
#   'into': '641.90',
#   'inth': '642.75',
#   'intl': '641.80',
#   'intc': '642.15',
#   'intvwap': '641.99',
#   'intv': '54540',
#   'intoi': '0',
#   'v': '9453068',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '02-01-2024 12:40:00',
#   'ssboe': '1704179400',
#   'into': '642.40',
#   'inth': '642.85',
#   'intl': '641.55',
#   'intc': '641.80',
#   'intvwap': '641.97',
#   'intv': '108424',
#   'intoi': '0',
#   'v': '9398528',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '02-01-2024 12:35:00',
#   'ssboe': '1704179100',
#   'into': '642.50',
#   'inth': '642.80',
#   'intl': '642.00',
#   'intc': '642.10',
#   'intvwap': '643.53',
#   'intv': '55974',
#   'intoi': '0',
#   'v': '9290104',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '02-01-2024 12:30:00',
#   'ssboe': '1704178800',
#   'into': '641.75',
#   'inth': '642.60',
#   'intl': '641.10',
#   'intc': '642.60',
#   'intvwap': '641.15',
#   'intv': '97762',
#   'intoi': '0',
#   'v': '9234130',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '02-01-2024 12:25:00',
#   'ssboe': '1704178500',
#   'into': '642.85',
#   'inth': '642.90',
#   'intl': '641.45',
#   'intc': '641.70',
#   'intvwap': '642.26',
#   'intv': '88113',
#   'intoi': '0',
#   'v': '9136368',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '02-01-2024 12:20:00',
#   'ssboe': '1704178200',
#   'into': '643.10',
#   'inth': '643.30',
#   'intl': '642.45',
#   'intc': '642.70',
#   'intvwap': '643.76',
#   'intv': '50235',
#   'intoi': '0',
#   'v': '9048255',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '02-01-2024 12:15:00',
#   'ssboe': '1704177900',
#   'into': '642.00',
#   'inth': '643.55',
#   'intl': '641.70',
#   'intc': '643.20',
#   'intvwap': '642.28',
#   'intv': '125863',
#   'intoi': '0',
#   'v': '8998020',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '02-01-2024 12:10:00',
#   'ssboe': '1704177600',
#   'into': '643.05',
#   'inth': '643.15',
#   'intl': '641.85',
#   'intc': '642.25',
#   'intvwap': '642.84',
#   'intv': '129160',
#   'intoi': '0',
#   'v': '8872157',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '02-01-2024 12:05:00',
#   'ssboe': '1704177300',
#   'into': '642.70',
#   'inth': '643.35',
#   'intl': '642.20',
#   'intc': '643.00',
#   'intvwap': '642.76',
#   'intv': '97204',
#   'intoi': '0',
#   'v': '8742997',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '02-01-2024 12:00:00',
#   'ssboe': '1704177000',
#   'into': '642.80',
#   'inth': '643.65',
#   'intl': '642.60',
#   'intc': '642.75',
#   'intvwap': '643.16',
#   'intv': '137335',
#   'intoi': '0',
#   'v': '8645793',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '02-01-2024 11:55:00',
#   'ssboe': '1704176700',
#   'into': '643.55',
#   'inth': '643.85',
#   'intl': '642.45',
#   'intc': '642.75',
#   'intvwap': '642.95',
#   'intv': '85974',
#   'intoi': '0',
#   'v': '8508458',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '02-01-2024 11:50:00',
#   'ssboe': '1704176400',
#   'into': '643.20',
#   'inth': '643.95',
#   'intl': '642.10',
#   'intc': '643.85',
#   'intvwap': '642.88',
#   'intv': '280928',
#   'intoi': '0',
#   'v': '8422484',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '02-01-2024 11:45:00',
#   'ssboe': '1704176100',
#   'into': '645.05',
#   'inth': '645.15',
#   'intl': '643.20',
#   'intc': '643.35',
#   'intvwap': '643.86',
#   'intv': '199491',
#   'intoi': '0',
#   'v': '8141556',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '02-01-2024 11:40:00',
#   'ssboe': '1704175800',
#   'into': '647.45',
#   'inth': '647.70',
#   'intl': '644.00',
#   'intc': '645.00',
#   'intvwap': '645.70',
#   'intv': '406976',
#   'intoi': '0',
#   'v': '7942065',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '02-01-2024 11:35:00',
#   'ssboe': '1704175500',
#   'into': '642.40',
#   'inth': '648.00',
#   'intl': '640.75',
#   'intc': '647.75',
#   'intvwap': '645.19',
#   'intv': '736132',
#   'intoi': '0',
#   'v': '7535089',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '02-01-2024 11:30:00',
#   'ssboe': '1704175200',
#   'into': '641.50',
#   'inth': '642.60',
#   'intl': '641.25',
#   'intc': '642.45',
#   'intvwap': '641.60',
#   'intv': '191396',
#   'intoi': '0',
#   'v': '6798957',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '02-01-2024 11:25:00',
#   'ssboe': '1704174900',
#   'into': '641.20',
#   'inth': '641.75',
#   'intl': '640.35',
#   'intc': '641.40',
#   'intvwap': '641.36',
#   'intv': '221051',
#   'intoi': '0',
#   'v': '6607561',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '02-01-2024 11:20:00',
#   'ssboe': '1704174600',
#   'into': '638.25',
#   'inth': '642.05',
#   'intl': '638.05',
#   'intc': '641.30',
#   'intvwap': '640.59',
#   'intv': '629486',
#   'intoi': '0',
#   'v': '6386510',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '02-01-2024 11:15:00',
#   'ssboe': '1704174300',
#   'into': '638.00',
#   'inth': '638.65',
#   'intl': '637.55',
#   'intc': '638.35',
#   'intvwap': '638.47',
#   'intv': '135574',
#   'intoi': '0',
#   'v': '5757024',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '02-01-2024 11:10:00',
#   'ssboe': '1704174000',
#   'into': '638.15',
#   'inth': '638.15',
#   'intl': '637.60',
#   'intc': '637.95',
#   'intvwap': '637.80',
#   'intv': '83517',
#   'intoi': '0',
#   'v': '5621450',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '02-01-2024 11:05:00',
#   'ssboe': '1704173700',
#   'into': '637.55',
#   'inth': '638.65',
#   'intl': '637.45',
#   'intc': '638.05',
#   'intvwap': '638.02',
#   'intv': '118725',
#   'intoi': '0',
#   'v': '5537933',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '02-01-2024 11:00:00',
#   'ssboe': '1704173400',
#   'into': '637.25',
#   'inth': '637.75',
#   'intl': '636.65',
#   'intc': '637.70',
#   'intvwap': '637.41',
#   'intv': '99497',
#   'intoi': '0',
#   'v': '5419208',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '02-01-2024 10:55:00',
#   'ssboe': '1704173100',
#   'into': '637.05',
#   'inth': '637.35',
#   'intl': '636.30',
#   'intc': '637.35',
#   'intvwap': '636.77',
#   'intv': '119999',
#   'intoi': '0',
#   'v': '5319711',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '02-01-2024 10:50:00',
#   'ssboe': '1704172800',
#   'into': '637.30',
#   'inth': '637.80',
#   'intl': '636.75',
#   'intc': '637.20',
#   'intvwap': '637.25',
#   'intv': '117846',
#   'intoi': '0',
#   'v': '5199712',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '02-01-2024 10:45:00',
#   'ssboe': '1704172500',
#   'into': '636.95',
#   'inth': '637.50',
#   'intl': '636.50',
#   'intc': '637.50',
#   'intvwap': '637.18',
#   'intv': '142313',
#   'intoi': '0',
#   'v': '5081866',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '02-01-2024 10:40:00',
#   'ssboe': '1704172200',
#   'into': '634.60',
#   'inth': '637.35',
#   'intl': '634.60',
#   'intc': '637.00',
#   'intvwap': '635.72',
#   'intv': '289550',
#   'intoi': '0',
#   'v': '4939553',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '02-01-2024 10:35:00',
#   'ssboe': '1704171900',
#   'into': '636.75',
#   'inth': '637.55',
#   'intl': '634.40',
#   'intc': '634.65',
#   'intvwap': '635.70',
#   'intv': '322231',
#   'intoi': '0',
#   'v': '4650003',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '02-01-2024 10:30:00',
#   'ssboe': '1704171600',
#   'into': '635.55',
#   'inth': '637.40',
#   'intl': '634.00',
#   'intc': '636.80',
#   'intvwap': '635.76',
#   'intv': '440793',
#   'intoi': '0',
#   'v': '4327772',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '02-01-2024 10:25:00',
#   'ssboe': '1704171300',
#   'into': '637.10',
#   'inth': '637.25',
#   'intl': '635.15',
#   'intc': '635.50',
#   'intvwap': '636.03',
#   'intv': '432432',
#   'intoi': '0',
#   'v': '3886979',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '02-01-2024 10:20:00',
#   'ssboe': '1704171000',
#   'into': '638.55',
#   'inth': '639.00',
#   'intl': '637.10',
#   'intc': '637.15',
#   'intvwap': '637.67',
#   'intv': '198052',
#   'intoi': '0',
#   'v': '3454547',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '02-01-2024 10:15:00',
#   'ssboe': '1704170700',
#   'into': '639.35',
#   'inth': '639.45',
#   'intl': '638.00',
#   'intc': '638.70',
#   'intvwap': '638.51',
#   'intv': '252323',
#   'intoi': '0',
#   'v': '3256495',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '02-01-2024 10:10:00',
#   'ssboe': '1704170400',
#   'into': '639.90',
#   'inth': '641.05',
#   'intl': '638.80',
#   'intc': '639.40',
#   'intvwap': '639.58',
#   'intv': '175702',
#   'intoi': '0',
#   'v': '3004172',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '02-01-2024 10:05:00',
#   'ssboe': '1704170100',
#   'into': '639.80',
#   'inth': '640.95',
#   'intl': '639.35',
#   'intc': '639.80',
#   'intvwap': '640.31',
#   'intv': '123227',
#   'intoi': '0',
#   'v': '2828470',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '02-01-2024 10:00:00',
#   'ssboe': '1704169800',
#   'into': '638.95',
#   'inth': '640.35',
#   'intl': '637.60',
#   'intc': '639.60',
#   'intvwap': '638.77',
#   'intv': '295125',
#   'intoi': '0',
#   'v': '2705243',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '02-01-2024 09:55:00',
#   'ssboe': '1704169500',
#   'into': '641.90',
#   'inth': '642.00',
#   'intl': '638.15',
#   'intc': '638.75',
#   'intvwap': '639.31',
#   'intv': '574197',
#   'intoi': '0',
#   'v': '2410118',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '02-01-2024 09:50:00',
#   'ssboe': '1704169200',
#   'into': '643.00',
#   'inth': '643.10',
#   'intl': '641.80',
#   'intc': '641.80',
#   'intvwap': '642.24',
#   'intv': '91851',
#   'intoi': '0',
#   'v': '1835921',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '02-01-2024 09:45:00',
#   'ssboe': '1704168900',
#   'into': '642.75',
#   'inth': '643.50',
#   'intl': '642.40',
#   'intc': '643.10',
#   'intvwap': '642.90',
#   'intv': '137227',
#   'intoi': '0',
#   'v': '1744070',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '02-01-2024 09:40:00',
#   'ssboe': '1704168600',
#   'into': '641.90',
#   'inth': '643.80',
#   'intl': '641.90',
#   'intc': '642.85',
#   'intvwap': '642.76',
#   'intv': '269904',
#   'intoi': '0',
#   'v': '1606843',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '02-01-2024 09:35:00',
#   'ssboe': '1704168300',
#   'into': '639.90',
#   'inth': '642.10',
#   'intl': '639.80',
#   'intc': '642.00',
#   'intvwap': '640.87',
#   'intv': '311125',
#   'intoi': '0',
#   'v': '1336939',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '02-01-2024 09:30:00',
#   'ssboe': '1704168000',
#   'into': '639.95',
#   'inth': '640.20',
#   'intl': '639.50',
#   'intc': '640.00',
#   'intvwap': '639.84',
#   'intv': '114961',
#   'intoi': '0',
#   'v': '1025814',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '02-01-2024 09:25:00',
#   'ssboe': '1704167700',
#   'into': '638.35',
#   'inth': '640.30',
#   'intl': '637.60',
#   'intc': '640.00',
#   'intvwap': '639.12',
#   'intv': '289589',
#   'intoi': '0',
#   'v': '910853',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '02-01-2024 09:20:00',
#   'ssboe': '1704167400',
#   'into': '638.65',
#   'inth': '640.00',
#   'intl': '638.15',
#   'intc': '638.60',
#   'intvwap': '638.96',
#   'intv': '229806',
#   'intoi': '0',
#   'v': '621264',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '02-01-2024 09:15:00',
#   'ssboe': '1704167100',
#   'into': '641.60',
#   'inth': '641.60',
#   'intl': '638.50',
#   'intc': '638.70',
#   'intvwap': '639.66',
#   'intv': '391458',
#   'intoi': '0',
#   'v': '391458',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '01-01-2024 15:25:00',
#   'ssboe': '1704102900',
#   'into': '639.15',
#   'inth': '639.95',
#   'intl': '638.00',
#   'intc': '638.30',
#   'intvwap': '638.90',
#   'intv': '272229',
#   'intoi': '0',
#   'v': '8291817',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '01-01-2024 15:20:00',
#   'ssboe': '1704102600',
#   'into': '640.70',
#   'inth': '640.80',
#   'intl': '638.05',
#   'intc': '639.30',
#   'intvwap': '639.41',
#   'intv': '329165',
#   'intoi': '0',
#   'v': '8019588',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '01-01-2024 15:15:00',
#   'ssboe': '1704102300',
#   'into': '642.25',
#   'inth': '642.30',
#   'intl': '640.40',
#   'intc': '640.65',
#   'intvwap': '641.30',
#   'intv': '345680',
#   'intoi': '0',
#   'v': '7690423',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '01-01-2024 15:10:00',
#   'ssboe': '1704102000',
#   'into': '641.65',
#   'inth': '642.55',
#   'intl': '641.05',
#   'intc': '642.05',
#   'intvwap': '641.79',
#   'intv': '294566',
#   'intoi': '0',
#   'v': '7344743',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '01-01-2024 15:05:00',
#   'ssboe': '1704101700',
#   'into': '643.50',
#   'inth': '643.75',
#   'intl': '641.55',
#   'intc': '641.55',
#   'intvwap': '642.55',
#   'intv': '305667',
#   'intoi': '0',
#   'v': '7050177',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '01-01-2024 15:00:00',
#   'ssboe': '1704101400',
#   'into': '643.80',
#   'inth': '644.50',
#   'intl': '642.60',
#   'intc': '643.65',
#   'intvwap': '643.58',
#   'intv': '367446',
#   'intoi': '0',
#   'v': '6744510',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '01-01-2024 14:55:00',
#   'ssboe': '1704101100',
#   'into': '643.65',
#   'inth': '644.20',
#   'intl': '643.45',
#   'intc': '643.70',
#   'intvwap': '643.80',
#   'intv': '210674',
#   'intoi': '0',
#   'v': '6377064',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '01-01-2024 14:50:00',
#   'ssboe': '1704100800',
#   'into': '644.45',
#   'inth': '644.60',
#   'intl': '643.50',
#   'intc': '643.55',
#   'intvwap': '643.82',
#   'intv': '200025',
#   'intoi': '0',
#   'v': '6166390',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '01-01-2024 14:45:00',
#   'ssboe': '1704100500',
#   'into': '644.55',
#   'inth': '644.80',
#   'intl': '643.70',
#   'intc': '644.50',
#   'intvwap': '643.90',
#   'intv': '138481',
#   'intoi': '0',
#   'v': '5966365',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '01-01-2024 14:40:00',
#   'ssboe': '1704100200',
#   'into': '644.10',
#   'inth': '645.15',
#   'intl': '643.75',
#   'intc': '644.70',
#   'intvwap': '644.53',
#   'intv': '235900',
#   'intoi': '0',
#   'v': '5827884',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '01-01-2024 14:35:00',
#   'ssboe': '1704099900',
#   'into': '644.25',
#   'inth': '644.50',
#   'intl': '643.70',
#   'intc': '644.05',
#   'intvwap': '643.98',
#   'intv': '137779',
#   'intoi': '0',
#   'v': '5591984',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '01-01-2024 14:30:00',
#   'ssboe': '1704099600',
#   'into': '644.15',
#   'inth': '644.80',
#   'intl': '643.95',
#   'intc': '644.30',
#   'intvwap': '644.31',
#   'intv': '111337',
#   'intoi': '0',
#   'v': '5454205',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '01-01-2024 14:25:00',
#   'ssboe': '1704099300',
#   'into': '644.65',
#   'inth': '644.85',
#   'intl': '644.05',
#   'intc': '644.25',
#   'intvwap': '644.34',
#   'intv': '220375',
#   'intoi': '0',
#   'v': '5342868',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '01-01-2024 14:20:00',
#   'ssboe': '1704099000',
#   'into': '644.95',
#   'inth': '645.15',
#   'intl': '644.45',
#   'intc': '644.60',
#   'intvwap': '644.83',
#   'intv': '231558',
#   'intoi': '0',
#   'v': '5122493',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '01-01-2024 14:15:00',
#   'ssboe': '1704098700',
#   'into': '645.25',
#   'inth': '645.55',
#   'intl': '644.50',
#   'intc': '645.20',
#   'intvwap': '644.83',
#   'intv': '125333',
#   'intoi': '0',
#   'v': '4890935',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '01-01-2024 14:10:00',
#   'ssboe': '1704098400',
#   'into': '644.80',
#   'inth': '645.60',
#   'intl': '644.40',
#   'intc': '645.15',
#   'intvwap': '645.32',
#   'intv': '93298',
#   'intoi': '0',
#   'v': '4765602',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '01-01-2024 14:05:00',
#   'ssboe': '1704098100',
#   'into': '645.30',
#   'inth': '645.50',
#   'intl': '644.50',
#   'intc': '644.75',
#   'intvwap': '644.82',
#   'intv': '65298',
#   'intoi': '0',
#   'v': '4672304',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '01-01-2024 14:00:00',
#   'ssboe': '1704097800',
#   'into': '644.90',
#   'inth': '645.35',
#   'intl': '644.70',
#   'intc': '645.35',
#   'intvwap': '645.31',
#   'intv': '91540',
#   'intoi': '0',
#   'v': '4607006',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '01-01-2024 13:55:00',
#   'ssboe': '1704097500',
#   'into': '644.30',
#   'inth': '645.20',
#   'intl': '644.20',
#   'intc': '644.85',
#   'intvwap': '644.81',
#   'intv': '55509',
#   'intoi': '0',
#   'v': '4515466',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '01-01-2024 13:50:00',
#   'ssboe': '1704097200',
#   'into': '645.35',
#   'inth': '645.40',
#   'intl': '644.30',
#   'intc': '644.40',
#   'intvwap': '644.81',
#   'intv': '63756',
#   'intoi': '0',
#   'v': '4459957',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '01-01-2024 13:45:00',
#   'ssboe': '1704096900',
#   'into': '644.95',
#   'inth': '645.35',
#   'intl': '644.80',
#   'intc': '645.20',
#   'intvwap': '644.81',
#   'intv': '54303',
#   'intoi': '0',
#   'v': '4396201',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '01-01-2024 13:40:00',
#   'ssboe': '1704096600',
#   'into': '644.50',
#   'inth': '645.40',
#   'intl': '644.40',
#   'intc': '644.90',
#   'intvwap': '644.81',
#   'intv': '94458',
#   'intoi': '0',
#   'v': '4341898',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '01-01-2024 13:35:00',
#   'ssboe': '1704096300',
#   'into': '644.40',
#   'inth': '644.95',
#   'intl': '644.25',
#   'intc': '644.55',
#   'intvwap': '644.81',
#   'intv': '72587',
#   'intoi': '0',
#   'v': '4247440',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '01-01-2024 13:30:00',
#   'ssboe': '1704096000',
#   'into': '644.75',
#   'inth': '644.80',
#   'intl': '643.80',
#   'intc': '644.35',
#   'intvwap': '644.18',
#   'intv': '130078',
#   'intoi': '0',
#   'v': '4174853',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '01-01-2024 13:25:00',
#   'ssboe': '1704095700',
#   'into': '644.05',
#   'inth': '644.75',
#   'intl': '644.00',
#   'intc': '644.55',
#   'intvwap': '644.00',
#   'intv': '48680',
#   'intoi': '0',
#   'v': '4044775',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '01-01-2024 13:20:00',
#   'ssboe': '1704095400',
#   'into': '644.45',
#   'inth': '644.70',
#   'intl': '644.00',
#   'intc': '644.00',
#   'intvwap': '644.26',
#   'intv': '68190',
#   'intoi': '0',
#   'v': '3996095',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '01-01-2024 13:15:00',
#   'ssboe': '1704095100',
#   'into': '644.65',
#   'inth': '645.00',
#   'intl': '644.10',
#   'intc': '644.30',
#   'intvwap': '644.85',
#   'intv': '75336',
#   'intoi': '0',
#   'v': '3927905',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '01-01-2024 13:10:00',
#   'ssboe': '1704094800',
#   'into': '644.35',
#   'inth': '644.70',
#   'intl': '644.10',
#   'intc': '644.70',
#   'intvwap': '644.02',
#   'intv': '46253',
#   'intoi': '0',
#   'v': '3852569',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '01-01-2024 13:05:00',
#   'ssboe': '1704094500',
#   'into': '644.25',
#   'inth': '644.50',
#   'intl': '644.00',
#   'intc': '644.30',
#   'intvwap': '644.86',
#   'intv': '47520',
#   'intoi': '0',
#   'v': '3806316',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '01-01-2024 13:00:00',
#   'ssboe': '1704094200',
#   'into': '644.30',
#   'inth': '644.55',
#   'intl': '644.05',
#   'intc': '644.30',
#   'intvwap': '643.75',
#   'intv': '33649',
#   'intoi': '0',
#   'v': '3758796',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '01-01-2024 12:55:00',
#   'ssboe': '1704093900',
#   'into': '644.30',
#   'inth': '644.65',
#   'intl': '644.05',
#   'intc': '644.45',
#   'intvwap': '644.01',
#   'intv': '43029',
#   'intoi': '0',
#   'v': '3725147',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '01-01-2024 12:50:00',
#   'ssboe': '1704093600',
#   'into': '644.50',
#   'inth': '644.50',
#   'intl': '644.00',
#   'intc': '644.40',
#   'intvwap': '644.88',
#   'intv': '40733',
#   'intoi': '0',
#   'v': '3682118',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '01-01-2024 12:45:00',
#   'ssboe': '1704093300',
#   'into': '644.30',
#   'inth': '644.50',
#   'intl': '644.00',
#   'intc': '644.40',
#   'intvwap': '643.89',
#   'intv': '36451',
#   'intoi': '0',
#   'v': '3641385',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '01-01-2024 12:40:00',
#   'ssboe': '1704093000',
#   'into': '644.55',
#   'inth': '644.70',
#   'intl': '644.00',
#   'intc': '644.10',
#   'intvwap': '643.77',
#   'intv': '32187',
#   'intoi': '0',
#   'v': '3604934',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '01-01-2024 12:35:00',
#   'ssboe': '1704092700',
#   'into': '643.75',
#   'inth': '644.75',
#   'intl': '643.75',
#   'intc': '644.35',
#   'intvwap': '644.39',
#   'intv': '69593',
#   'intoi': '0',
#   'v': '3572747',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '01-01-2024 12:30:00',
#   'ssboe': '1704092400',
#   'into': '643.80',
#   'inth': '644.15',
#   'intl': '643.50',
#   'intc': '643.95',
#   'intvwap': '644.15',
#   'intv': '46092',
#   'intoi': '0',
#   'v': '3503154',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '01-01-2024 12:25:00',
#   'ssboe': '1704092100',
#   'into': '643.90',
#   'inth': '644.30',
#   'intl': '643.70',
#   'intc': '643.70',
#   'intvwap': '643.50',
#   'intv': '48314',
#   'intoi': '0',
#   'v': '3457062',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '01-01-2024 12:20:00',
#   'ssboe': '1704091800',
#   'into': '644.00',
#   'inth': '644.05',
#   'intl': '643.50',
#   'intc': '643.70',
#   'intvwap': '643.99',
#   'intv': '35932',
#   'intoi': '0',
#   'v': '3408748',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '01-01-2024 12:15:00',
#   'ssboe': '1704091500',
#   'into': '644.60',
#   'inth': '644.80',
#   'intl': '643.50',
#   'intc': '643.85',
#   'intvwap': '643.81',
#   'intv': '87361',
#   'intoi': '0',
#   'v': '3372816',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '01-01-2024 12:10:00',
#   'ssboe': '1704091200',
#   'into': '644.70',
#   'inth': '645.00',
#   'intl': '644.40',
#   'intc': '644.55',
#   'intvwap': '644.98',
#   'intv': '37751',
#   'intoi': '0',
#   'v': '3285455',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '01-01-2024 12:05:00',
#   'ssboe': '1704090900',
#   'into': '644.95',
#   'inth': '645.00',
#   'intl': '644.35',
#   'intc': '644.95',
#   'intvwap': '644.98',
#   'intv': '23983',
#   'intoi': '0',
#   'v': '3247704',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '01-01-2024 12:00:00',
#   'ssboe': '1704090600',
#   'into': '644.80',
#   'inth': '645.05',
#   'intl': '644.40',
#   'intc': '644.75',
#   'intvwap': '644.98',
#   'intv': '57195',
#   'intoi': '0',
#   'v': '3223721',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '01-01-2024 11:55:00',
#   'ssboe': '1704090300',
#   'into': '645.05',
#   'inth': '645.10',
#   'intl': '644.80',
#   'intc': '644.95',
#   'intvwap': '644.98',
#   'intv': '26194',
#   'intoi': '0',
#   'v': '3166526',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '01-01-2024 11:50:00',
#   'ssboe': '1704090000',
#   'into': '644.85',
#   'inth': '645.05',
#   'intl': '644.80',
#   'intc': '645.00',
#   'intvwap': '644.98',
#   'intv': '24186',
#   'intoi': '0',
#   'v': '3140332',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '01-01-2024 11:45:00',
#   'ssboe': '1704089700',
#   'into': '644.90',
#   'inth': '645.00',
#   'intl': '644.70',
#   'intc': '644.90',
#   'intvwap': '644.98',
#   'intv': '17442',
#   'intoi': '0',
#   'v': '3116146',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '01-01-2024 11:40:00',
#   'ssboe': '1704089400',
#   'into': '645.10',
#   'inth': '645.40',
#   'intl': '644.70',
#   'intc': '644.75',
#   'intvwap': '644.98',
#   'intv': '24168',
#   'intoi': '0',
#   'v': '3098704',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '01-01-2024 11:35:00',
#   'ssboe': '1704089100',
#   'into': '645.45',
#   'inth': '645.55',
#   'intl': '644.75',
#   'intc': '645.15',
#   'intvwap': '644.98',
#   'intv': '36854',
#   'intoi': '0',
#   'v': '3074536',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '01-01-2024 11:30:00',
#   'ssboe': '1704088800',
#   'into': '645.25',
#   'inth': '645.85',
#   'intl': '645.05',
#   'intc': '645.35',
#   'intvwap': '644.98',
#   'intv': '50930',
#   'intoi': '0',
#   'v': '3037682',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '01-01-2024 11:25:00',
#   'ssboe': '1704088500',
#   'into': '645.00',
#   'inth': '645.45',
#   'intl': '644.90',
#   'intc': '645.30',
#   'intvwap': '644.98',
#   'intv': '32202',
#   'intoi': '0',
#   'v': '2986752',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '01-01-2024 11:20:00',
#   'ssboe': '1704088200',
#   'into': '645.00',
#   'inth': '645.10',
#   'intl': '644.75',
#   'intc': '644.95',
#   'intvwap': '644.98',
#   'intv': '38421',
#   'intoi': '0',
#   'v': '2954550',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '01-01-2024 11:15:00',
#   'ssboe': '1704087900',
#   'into': '645.20',
#   'inth': '645.40',
#   'intl': '644.35',
#   'intc': '644.80',
#   'intvwap': '644.98',
#   'intv': '53856',
#   'intoi': '0',
#   'v': '2916129',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '01-01-2024 11:10:00',
#   'ssboe': '1704087600',
#   'into': '646.70',
#   'inth': '646.85',
#   'intl': '644.70',
#   'intc': '645.35',
#   'intvwap': '645.53',
#   'intv': '100166',
#   'intoi': '0',
#   'v': '2862273',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '01-01-2024 11:05:00',
#   'ssboe': '1704087300',
#   'into': '645.75',
#   'inth': '646.75',
#   'intl': '645.60',
#   'intc': '646.65',
#   'intvwap': '646.48',
#   'intv': '104247',
#   'intoi': '0',
#   'v': '2762107',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '01-01-2024 11:00:00',
#   'ssboe': '1704087000',
#   'into': '646.10',
#   'inth': '646.50',
#   'intl': '645.60',
#   'intc': '645.65',
#   'intvwap': '645.76',
#   'intv': '89183',
#   'intoi': '0',
#   'v': '2657860',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '01-01-2024 10:55:00',
#   'ssboe': '1704086700',
#   'into': '646.45',
#   'inth': '646.60',
#   'intl': '645.85',
#   'intc': '646.05',
#   'intvwap': '646.55',
#   'intv': '59344',
#   'intoi': '0',
#   'v': '2568677',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '01-01-2024 10:50:00',
#   'ssboe': '1704086400',
#   'into': '645.90',
#   'inth': '646.50',
#   'intl': '645.60',
#   'intc': '646.20',
#   'intvwap': '645.96',
#   'intv': '64031',
#   'intoi': '0',
#   'v': '2509333',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '01-01-2024 10:45:00',
#   'ssboe': '1704086100',
#   'into': '646.05',
#   'inth': '646.40',
#   'intl': '645.65',
#   'intc': '645.85',
#   'intvwap': '645.88',
#   'intv': '107384',
#   'intoi': '0',
#   'v': '2445302',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '01-01-2024 10:40:00',
#   'ssboe': '1704085800',
#   'into': '646.15',
#   'inth': '646.90',
#   'intl': '645.80',
#   'intc': '646.00',
#   'intvwap': '646.36',
#   'intv': '185637',
#   'intoi': '0',
#   'v': '2337918',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '01-01-2024 10:35:00',
#   'ssboe': '1704085500',
#   'into': '645.75',
#   'inth': '646.15',
#   'intl': '645.10',
#   'intc': '646.00',
#   'intvwap': '645.68',
#   'intv': '76850',
#   'intoi': '0',
#   'v': '2152281',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '01-01-2024 10:30:00',
#   'ssboe': '1704085200',
#   'into': '646.00',
#   'inth': '646.00',
#   'intl': '645.40',
#   'intc': '645.70',
#   'intvwap': '645.82',
#   'intv': '64057',
#   'intoi': '0',
#   'v': '2075431',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '01-01-2024 10:25:00',
#   'ssboe': '1704084900',
#   'into': '644.85',
#   'inth': '646.00',
#   'intl': '644.75',
#   'intc': '645.80',
#   'intvwap': '645.52',
#   'intv': '131218',
#   'intoi': '0',
#   'v': '2011374',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '01-01-2024 10:20:00',
#   'ssboe': '1704084600',
#   'into': '644.85',
#   'inth': '645.50',
#   'intl': '644.20',
#   'intc': '644.80',
#   'intvwap': '644.69',
#   'intv': '144646',
#   'intoi': '0',
#   'v': '1880156',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '01-01-2024 10:15:00',
#   'ssboe': '1704084300',
#   'into': '645.00',
#   'inth': '645.00',
#   'intl': '644.60',
#   'intc': '644.80',
#   'intvwap': '645.09',
#   'intv': '51038',
#   'intoi': '0',
#   'v': '1735510',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '01-01-2024 10:10:00',
#   'ssboe': '1704084000',
#   'into': '645.15',
#   'inth': '645.20',
#   'intl': '644.60',
#   'intc': '644.95',
#   'intvwap': '644.87',
#   'intv': '70956',
#   'intoi': '0',
#   'v': '1684472',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '01-01-2024 10:05:00',
#   'ssboe': '1704083700',
#   'into': '644.95',
#   'inth': '645.50',
#   'intl': '644.50',
#   'intc': '645.10',
#   'intvwap': '645.16',
#   'intv': '60733',
#   'intoi': '0',
#   'v': '1613516',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '01-01-2024 10:00:00',
#   'ssboe': '1704083400',
#   'into': '645.80',
#   'inth': '646.00',
#   'intl': '644.80',
#   'intc': '644.90',
#   'intvwap': '645.21',
#   'intv': '86735',
#   'intoi': '0',
#   'v': '1552783',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '01-01-2024 09:55:00',
#   'ssboe': '1704083100',
#   'into': '645.30',
#   'inth': '646.45',
#   'intl': '645.30',
#   'intc': '645.75',
#   'intvwap': '646.00',
#   'intv': '263437',
#   'intoi': '0',
#   'v': '1466048',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '01-01-2024 09:50:00',
#   'ssboe': '1704082800',
#   'into': '644.95',
#   'inth': '645.95',
#   'intl': '644.30',
#   'intc': '645.40',
#   'intvwap': '645.33',
#   'intv': '151163',
#   'intoi': '0',
#   'v': '1202611',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '01-01-2024 09:45:00',
#   'ssboe': '1704082500',
#   'into': '643.50',
#   'inth': '645.05',
#   'intl': '643.10',
#   'intc': '644.80',
#   'intvwap': '644.09',
#   'intv': '131907',
#   'intoi': '0',
#   'v': '1051448',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '01-01-2024 09:40:00',
#   'ssboe': '1704082200',
#   'into': '643.25',
#   'inth': '644.45',
#   'intl': '643.00',
#   'intc': '643.30',
#   'intvwap': '643.69',
#   'intv': '85386',
#   'intoi': '0',
#   'v': '919541',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '01-01-2024 09:35:00',
#   'ssboe': '1704081900',
#   'into': '644.50',
#   'inth': '645.00',
#   'intl': '643.25',
#   'intc': '643.35',
#   'intvwap': '644.13',
#   'intv': '165292',
#   'intoi': '0',
#   'v': '834155',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '01-01-2024 09:30:00',
#   'ssboe': '1704081600',
#   'into': '643.70',
#   'inth': '645.00',
#   'intl': '643.05',
#   'intc': '644.80',
#   'intvwap': '643.96',
#   'intv': '92119',
#   'intoi': '0',
#   'v': '668863',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '01-01-2024 09:25:00',
#   'ssboe': '1704081300',
#   'into': '645.55',
#   'inth': '645.65',
#   'intl': '643.70',
#   'intc': '643.80',
#   'intvwap': '644.56',
#   'intv': '100192',
#   'intoi': '0',
#   'v': '576744',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '01-01-2024 09:20:00',
#   'ssboe': '1704081000',
#   'into': '643.50',
#   'inth': '645.55',
#   'intl': '643.15',
#   'intc': '645.50',
#   'intvwap': '644.20',
#   'intv': '174483',
#   'intoi': '0',
#   'v': '476552',
#   'oi': '0'},
#  {'stat': 'Ok',
#   'time': '01-01-2024 09:15:00',
#   'ssboe': '1704080700',
#   'into': '642.30',
#   'inth': '644.50',
#   'intl': '641.00',
#   'intc': '643.75',
#   'intvwap': '642.83',
#   'intv': '279909',
#   'intoi': '0',
#   'v': '302069',
#   'oi': '0'}]

# %%
data = pd.DataFrame(ret)

# %%
_915_time = dt.datetime.now().strftime("%d-%m-%Y 09:15:00")
_915_time
# Out:
# '03-01-2024 09:15:00'

# %%
data.set_index('time')
# Out:
#                     stat       ssboe    into    inth    intl    intc intvwap  \
# time
# 03-01-2024 15:25:00   Ok  1704275700  643.40  644.90  643.20  644.50  644.44
# 03-01-2024 15:20:00   Ok  1704275400  643.30  643.90  643.05  643.45  643.19
# 03-01-2024 15:15:00   Ok  1704275100  643.95  643.95  643.00  643.25  643.63
# 03-01-2024 15:10:00   Ok  1704274800  643.45  644.25  643.20  643.75  643.69
# 03-01-2024 15:05:00   Ok  1704274500  643.35  643.90  642.90  643.50  643.17
# ...                  ...         ...     ...     ...     ...     ...     ...
# 01-01-2024 09:35:00   Ok  1704081900  644.50  645.00  643.25  643.35  644.13
# 01-01-2024 09:30:00   Ok  1704081600  643.70  645.00  643.05  644.80  643.96
# 01-01-2024 09:25:00   Ok  1704081300  645.55  645.65  643.70  643.80  644.56
# 01-01-2024 09:20:00   Ok  1704081000  643.50  645.55  643.15  645.50  644.20
# 01-01-2024 09:15:00   Ok  1704080700  642.30  644.50  641.00  643.75  642.83
#
#                        intv intoi         v oi
# time
# 03-01-2024 15:25:00  231881     0  14566503  0
# 03-01-2024 15:20:00  307069     0  14334622  0
# 03-01-2024 15:15:00  305953     0  14027553  0
# 03-01-2024 15:10:00  262946     0  13721600  0
# 03-01-2024 15:05:00  262319     0  13458654  0
# ...                     ...   ...       ... ..
# 01-01-2024 09:35:00  165292     0    834155  0
# 01-01-2024 09:30:00   92119     0    668863  0
# 01-01-2024 09:25:00  100192     0    576744  0
# 01-01-2024 09:20:00  174483     0    476552  0
# 01-01-2024 09:15:00  279909     0    302069  0
#
# [225 rows x 11 columns]

# %%
# Out:
# 476552

# %%
_5_min_high = float(data['inth'].loc[_915_time])
# Out:
# 639.0

# %%
def fatch_live_data(sym, days=5) -> pd.DataFrame:
    start_time = (dt.datetime.now() - dt.timedelta(days=5)).timestamp()
    ret = api.get_time_price_series(exchange="NSE", token=str(nse_master['Token'].loc['SBIN']), starttime=start_time, interval=str(days))
    data = pd.DataFrame(ret)
    data.columns = [
        'stat',
        'time',
        'ssboe',
        'open',
        'high',
        'low',
        'close',
        'vwap',
        'intvolume',
        'oi',
        'v',
        'oi'
    ]
    data = data.set_index("time")
    return data

fatch_live_data("ACC")
# Out:
#                     stat       ssboe    open    high     low   close    vwap  \
# time
# 03-01-2024 15:25:00   Ok  1704275700  643.40  644.90  643.20  644.50  644.44
# 03-01-2024 15:20:00   Ok  1704275400  643.30  643.90  643.05  643.45  643.19
# 03-01-2024 15:15:00   Ok  1704275100  643.95  643.95  643.00  643.25  643.63
# 03-01-2024 15:10:00   Ok  1704274800  643.45  644.25  643.20  643.75  643.69
# 03-01-2024 15:05:00   Ok  1704274500  643.35  643.90  642.90  643.50  643.17
# ...                  ...         ...     ...     ...     ...     ...     ...
# 01-01-2024 09:35:00   Ok  1704081900  644.50  645.00  643.25  643.35  644.13
# 01-01-2024 09:30:00   Ok  1704081600  643.70  645.00  643.05  644.80  643.96
# 01-01-2024 09:25:00   Ok  1704081300  645.55  645.65  643.70  643.80  644.56
# 01-01-2024 09:20:00   Ok  1704081000  643.50  645.55  643.15  645.50  644.20
# 01-01-2024 09:15:00   Ok  1704080700  642.30  644.50  641.00  643.75  642.83
#
#                     intvolume oi         v oi
# time
# 03-01-2024 15:25:00    231881  0  14566503  0
# 03-01-2024 15:20:00    307069  0  14334622  0
# 03-01-2024 15:15:00    305953  0  14027553  0
# 03-01-2024 15:10:00    262946  0  13721600  0
# 03-01-2024 15:05:00    262319  0  13458654  0
# ...                       ... ..       ... ..
# 01-01-2024 09:35:00    165292  0    834155  0
# 01-01-2024 09:30:00     92119  0    668863  0
# 01-01-2024 09:25:00    100192  0    576744  0
# 01-01-2024 09:20:00    174483  0    476552  0
# 01-01-2024 09:15:00    279909  0    302069  0
#
# [225 rows x 11 columns]
